# %% [markdown]
# <a href="https://colab.research.google.com/github/XiwenLiuLoveML/IBM-DataScience-ProfessionalCertificate/blob/main/ECGproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#connect to google drive
# change this to connect to cloud database when needed
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import librarys
import numpy as np
import xml.etree.ElementTree as ET
import os
import fnmatch
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models

# %%
# don't run this part. This part is to test and find index of tags
# (find correct location of the data in xml)

#parse xml files
mytree = ET.parse('/content/drive/MyDrive/ECGproject/AF100/69045.xml')
myroot = mytree.getroot()

x=0
for child in myroot:
  print(x,child.tag)
  x = x+1
# extract the first label
for child in myroot[4][0]:
  print(child.text)
# extract I lead data:
x = 0
for child in myroot[11]:
  print(x, child.tag)
  x = x+1

x = 0
for child in myroot[11][5]:
  print(x,child.tag)
  x = x+1

#find the index for I, II and V1~V6
for x in range(5,17):
  print(x,myroot[11][x][6].text)

# check the index for I, II an V1~V6:
for x in list([5,6])+list(range(11,17)):
  print(x,myroot[11][x][6].text)

# according to the paper, only 8 indepent leads data are needed
# extract ecg data and store it into a numpy array with shape (5000,8)
data=[]
for x in list([5,6])+list(range(11,17)):
  data.append([int(i) for i in myroot[11][x][10].text.split()])
thisfiledata= np.array(data)
#tensorflow takes numpy.array

# %%
# parse multiple XML files in the same folder
#(ones:diagnosedd as positive)
path = "/content/drive/MyDrive/ECGproject/AF100"

ECGlist = []
for filename in os.listdir(path):
  if fnmatch.fnmatch(filename, '*.xml'):
    with open(os.path.join(path, filename), "r") as data:
      tree = ET.parse(data)
      root = tree.getroot()
      data = []
      for x in list([5,6])+list(range(11,17)):
        data.append([int(i) for i in root[11][x][10].text.split()])
      dataT=np.array(data).T
      ECGlist.append(dataT)
ECGone = np.array(ECGlist)
print("ECGone shape :",ECGone.shape)

#print out the max, min and mean value

#for x in ["max", "min", "mean"]:
#  print("ECGone", x, ":",getattr(ECGone,x)())
# Out:
# ECGone shape : (100, 5000, 8)

# %%
# parse multiple XML files in the same folder
# (zeros:diagnosed as negative)
path = "/content/drive/MyDrive/ECGproject/NM1000"

ECGlist = []
for filename in os.listdir(path):
  if fnmatch.fnmatch(filename, '*.xml'):
    with open(os.path.join(path, filename), "r") as data:
      tree = ET.parse(data)
      root = tree.getroot()
      data = []
      for x in list([5,6])+list(range(11,17)):
        data.append([int(i) for i in root[11][x][10].text.split()])
      dataT=np.array(data).T
      ECGlist.append(dataT)
ECGzeroTotal = np.array(ECGlist)
print("ECGzeroTotal shape :",ECGzeroTotal.shape)


#select 100 samples from normal cases randomly
ECGzero = ECGzeroTotal[np.random.choice(1000, 100),:, :]
print("ECGzero shape :",ECGzero.shape)

#print out the max, min and mean value
#for x in ["max", "min", "mean"]:
#  print("ECGzero", x, ":",getattr(ECGzero,x)())
# Out:
# ECGzeroTotal shape : (1000, 5000, 8)
# ECGzero shape : (100, 5000, 8)

# %%
# let's have a look of the data

#data_inspect = ECGzero
data_inspect = ECGone

patientIndex = np.random.choice(100)


# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(8,figsize=(50, 60))

# For Lead I
axis[0].plot(data_inspect[patientIndex, :, 0])
axis[0].set_title("ECG Lead I")

# For Lead II
axis[1].plot(data_inspect[patientIndex, :, 1])
axis[1].set_title("ECG Lead II")

# For Lead V1~V6
for i in np.arange(2,8):
  axis[i].plot(data_inspect[patientIndex, :, i])
  axis[i].set_title("ECG Lead V"+str(i-1))

# Combine all the operations and display
plt.show()

# %%
# split the data into test, train and validation
#from sklearn.model_selection import train_test_split
# split the data into test data and the rest data
one_rest, one_test = train_test_split(ECGone, test_size=0.20, random_state=43)
zero_rest, zero_test = train_test_split(ECGzero, test_size=0.20, random_state=43)

# split the data into train data and the validation data
one_train, one_valid = train_test_split(one_rest, test_size=10, random_state=43)
zero_train, zero_valid = train_test_split(zero_rest, test_size=10, random_state=43)

# check the shape
print("one train size: ",one_train.shape)
print("one test size: ",one_test.shape)
print("one validation size: ",one_valid.shape)
print("zero train size: ",zero_train.shape)
print("zero test size: ",zero_test.shape)
print("zero validation size: ",zero_valid.shape)
# Out:
# one train size:  (70, 5000, 8)
# one test size:  (20, 5000, 8)
# one validation size:  (10, 5000, 8)
# zero train size:  (70, 5000, 8)
# zero test size:  (20, 5000, 8)
# zero validation size:  (10, 5000, 8)

# %%
# concatenate the ones and zeros
# to create the the combo of train, test and valid data
x_train_combo = np.concatenate((one_train,zero_train))
x_test_combo = np.concatenate((one_test,zero_test))
x_valid_combo = np.concatenate((one_valid,zero_valid))
# create y (labels for the data)
y_train = np.concatenate((np.ones(70), np.zeros(70)))
y_test= np.concatenate((np.ones(20),np.zeros(20)))
y_valid = np.concatenate((np.ones(10),np.zeros(10)))

# %%
# zero padding
pad_train = np.zeros((140,60,8))
x_train_pad = np.concatenate((pad_train,x_train_combo,pad_train),axis =1)
pad_test = np.zeros((40,60,8))
x_test_pad = np.concatenate((pad_test,x_test_combo,pad_test),axis =1)
pad_valid = np.zeros((20,60,8))
x_valid_pad = np.concatenate((pad_valid, x_valid_combo, pad_valid), axis = 1)
print("training shape:",x_train_pad.shape)
print("testing shape:",x_test_pad.shape)
print("validation shape:",x_valid_pad.shape)
# Out:
# training shape: (140, 5120, 8)
# testing shape: (40, 5120, 8)
# validation shape: (20, 5120, 8)

# %%
# Make sure images have shape (5120,8, 1) (for tensorflow keras to process)
x_train = np.expand_dims(x_train_pad, -1)
x_test = np.expand_dims(x_test_pad, -1)
x_valid = np.expand_dims(x_valid_pad, -1)
print("train input shape:",x_train.shape)
print("test input shape:",x_test.shape)
print("valid input shape:",x_valid.shape)
# Out:
# train input shape: (140, 5120, 8, 1)
# test input shape: (40, 5120, 8, 1)
# valid input shape: (20, 5120, 8, 1)

# %%
# Define Resblock
def ResBlock(inputs,channelsize, K):

  #left arm
  x_left = layers.BatchNormalization()(inputs)
  x_left = layers.ReLU()(x_left)
  x_left = layers.Conv2D(filters = channelsize, kernel_size=(K,1))(x_left)
  x_left = layers.BatchNormalization()(x_left)
  x_left = layers.ReLU()(x_left)
  x_left = layers.Conv2D(filters = channelsize, kernel_size=(K,1),strides = (2,1))(x_left)

  # calculate the maxpooling pool size
  max_K = inputs.shape[1]-int((inputs.shape[1]-2*K+1)/2)*2
  #right arm
  x_right = layers.Conv2D(filters = channelsize, kernel_size=(1,1))(inputs)
  x_right = layers.MaxPooling2D(pool_size=(max_K,1),strides=(2, 1))(x_right)

  # sum up
  outputs = layers.Add()([x_left, x_right])
  return outputs

# %%
# Model Arcitecture
inputs = keras.Input(shape=(5120,8,1))
#temporal axis pooling
block1 = ResBlock(inputs,16,7)
block2 = ResBlock(block1,16,7)
block3 = ResBlock(block2,16,7)
block3output = layers.Dropout(0.2)(block3)
block4 = ResBlock(block3output,32,5)
block5 = ResBlock(block4,32,5)
block6 = ResBlock(block5,32,5)
block6output = layers.Dropout(0.2)(block6)
block7 = ResBlock(block6,64,3)
block8 = ResBlock(block7,64,3)
block9 = ResBlock(block8,64,3)
block9output = layers.Dropout(0.2)(block9)

#lead axis pooling
x = layers.Conv2D(filters = 128, kernel_size=(1,8))(block9output)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.2)(x)

#fully connection
x = layers.Flatten()(x)
outputs = layers.Dense(2, activation='softmax')(x)

model = keras.Model(inputs=inputs, outputs=outputs, name="ECG_ResBlock")
model.summary()
# Out:
# Model: "ECG_ResBlock"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5120, 8, 1)]         0         []
#
#  batch_normalization (Batch  (None, 5120, 8, 1)           4         ['input_1[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 5120, 8, 1)           0         ['batch_normalization[0][0]']
#
#  conv2d (Conv2D)             (None, 5114, 8, 16)          128       ['re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5114, 8, 16)          64        ['conv2d[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 5114, 8, 16)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 5120, 8, 16)          32        ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 2554, 8, 16)          1808      ['re_lu_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 2554, 8, 16)          0         ['conv2d_2[0][0]']
#  D)
#
#  add (Add)                   (None, 2554, 8, 16)          0         ['conv2d_1[0][0]',
#                                                                      'max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 2554, 8, 16)          64        ['add[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 2554, 8, 16)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 2548, 8, 16)          1808      ['re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 2548, 8, 16)          64        ['conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 2548, 8, 16)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 2554, 8, 16)          272       ['add[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 1271, 8, 16)          1808      ['re_lu_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 1271, 8, 16)          0         ['conv2d_5[0][0]']
#  g2D)
#
#  add_1 (Add)                 (None, 1271, 8, 16)          0         ['conv2d_4[0][0]',
#                                                                      'max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 1271, 8, 16)          64        ['add_1[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 1271, 8, 16)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 1265, 8, 16)          1808      ['re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 1265, 8, 16)          64        ['conv2d_6[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 1265, 8, 16)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 1271, 8, 16)          272       ['add_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 630, 8, 16)           1808      ['re_lu_5[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 630, 8, 16)           0         ['conv2d_8[0][0]']
#  g2D)
#
#  add_2 (Add)                 (None, 630, 8, 16)           0         ['conv2d_7[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  dropout (Dropout)           (None, 630, 8, 16)           0         ['add_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 630, 8, 16)           64        ['dropout[0][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 630, 8, 16)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 626, 8, 32)           2592      ['re_lu_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 626, 8, 32)           128       ['conv2d_9[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 626, 8, 32)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_11 (Conv2D)          (None, 630, 8, 32)           544       ['dropout[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 311, 8, 32)           5152      ['re_lu_7[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 311, 8, 32)           0         ['conv2d_11[0][0]']
#  g2D)
#
#  add_3 (Add)                 (None, 311, 8, 32)           0         ['conv2d_10[0][0]',
#                                                                      'max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 311, 8, 32)           128       ['add_3[0][0]']
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 311, 8, 32)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_12 (Conv2D)          (None, 307, 8, 32)           5152      ['re_lu_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 307, 8, 32)           128       ['conv2d_12[0][0]']
#  chNormalization)
#
#  re_lu_9 (ReLU)              (None, 307, 8, 32)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_14 (Conv2D)          (None, 311, 8, 32)           1056      ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 152, 8, 32)           5152      ['re_lu_9[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 152, 8, 32)           0         ['conv2d_14[0][0]']
#  g2D)
#
#  add_4 (Add)                 (None, 152, 8, 32)           0         ['conv2d_13[0][0]',
#                                                                      'max_pooling2d_4[0][0]']
#
#  batch_normalization_10 (Ba  (None, 152, 8, 32)           128       ['add_4[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 152, 8, 32)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 148, 8, 32)           5152      ['re_lu_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 148, 8, 32)           128       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 148, 8, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 152, 8, 32)           1056      ['add_4[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 72, 8, 32)            5152      ['re_lu_11[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 72, 8, 32)            0         ['conv2d_17[0][0]']
#  g2D)
#
#  add_5 (Add)                 (None, 72, 8, 32)            0         ['conv2d_16[0][0]',
#                                                                      'max_pooling2d_5[0][0]']
#
#  batch_normalization_12 (Ba  (None, 72, 8, 32)            128       ['add_5[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 72, 8, 32)            0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 70, 8, 64)            6208      ['re_lu_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 70, 8, 64)            256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 70, 8, 64)            0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 72, 8, 64)            2112      ['add_5[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 34, 8, 64)            12352     ['re_lu_13[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 34, 8, 64)            0         ['conv2d_20[0][0]']
#  g2D)
#
#  add_6 (Add)                 (None, 34, 8, 64)            0         ['conv2d_19[0][0]',
#                                                                      'max_pooling2d_6[0][0]']
#
#  batch_normalization_14 (Ba  (None, 34, 8, 64)            256       ['add_6[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 34, 8, 64)            0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 32, 8, 64)            12352     ['re_lu_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 32, 8, 64)            256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 32, 8, 64)            0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 34, 8, 64)            4160      ['add_6[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 15, 8, 64)            12352     ['re_lu_15[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 15, 8, 64)            0         ['conv2d_23[0][0]']
#  g2D)
#
#  add_7 (Add)                 (None, 15, 8, 64)            0         ['conv2d_22[0][0]',
#                                                                      'max_pooling2d_7[0][0]']
#
#  batch_normalization_16 (Ba  (None, 15, 8, 64)            256       ['add_7[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 15, 8, 64)            0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 13, 8, 64)            12352     ['re_lu_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 13, 8, 64)            256       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 13, 8, 64)            0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 15, 8, 64)            4160      ['add_7[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 6, 8, 64)             12352     ['re_lu_17[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 6, 8, 64)             0         ['conv2d_26[0][0]']
#  g2D)
#
#  add_8 (Add)                 (None, 6, 8, 64)             0         ['conv2d_25[0][0]',
#                                                                      'max_pooling2d_8[0][0]']
#
#  dropout_2 (Dropout)         (None, 6, 8, 64)             0         ['add_8[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 6, 1, 128)            65664     ['dropout_2[0][0]']
#
#  batch_normalization_18 (Ba  (None, 6, 1, 128)            512       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 6, 1, 128)            0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  dropout_3 (Dropout)         (None, 6, 1, 128)            0         ['re_lu_18[0][0]']
#
#  flatten (Flatten)           (None, 768)                  0         ['dropout_3[0][0]']
#
#  dense (Dense)               (None, 2)                    1538      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 189302 (739.46 KB)
# Trainable params: 187828 (733.70 KB)
# Non-trainable params: 1474 (5.76 KB)
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, "model graph.png", show_shapes=True)

# %%
# compile and fit the model
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.RMSprop(),
    metrics=["accuracy"],
)
history = model.fit(x_train, y_train, batch_size=16, epochs=5)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 9/9 [==============================] - 31s 2s/step - loss: 0.8027 - accuracy: 0.6286
# Epoch 2/5
# 9/9 [==============================] - 20s 2s/step - loss: 0.4505 - accuracy: 0.7286
# Epoch 3/5
# 9/9 [==============================] - 20s 2s/step - loss: 0.2797 - accuracy: 0.8643
# Epoch 4/5
# 9/9 [==============================] - 21s 2s/step - loss: 0.1490 - accuracy: 0.9571
# Epoch 5/5
# 9/9 [==============================] - 22s 2s/step - loss: 0.1793 - accuracy: 0.9143

# %%
# evaluate the model using test data set, adjust the hyperparameters
test_scores = model.evaluate(x_test, y_test, verbose=2)
print("Test accuracy:", test_scores[1])
# Out:
# 2/2 - 3s - loss: 0.7567 - accuracy: 0.8750 - 3s/epoch - 2s/step
# Test accuracy: 0.875

# %%
# evaluate the model using test data set, adjust the hyperparameters
valid_scores = model.evaluate(x_valid, y_valid, verbose=2)
print("Validadtion accuracy:", valid_scores[1])
# Out:
# 1/1 - 1s - loss: 0.2741 - accuracy: 0.9000 - 573ms/epoch - 573ms/step
# Validadtion accuracy: 0.8999999761581421
